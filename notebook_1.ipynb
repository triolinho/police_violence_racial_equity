# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_police_killings = pd.read_csv('police_killings_MPV.csv')
# Out:
# /Users/andrewtriola/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (21,22,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_police_killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8427 entries, 0 to 8426
# Data columns (total 68 columns):
#  #   Column                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                      --------------  -----
#  0   Victim's name                                                                                                                                                               8427 non-null   object
#  1   Victim's age                                                                                                                                                                8427 non-null   object
# ...

# %%
col_list = df_police_killings.columns[:29]

# %%
col_list
# Out:
# Index(['Victim's name', 'Victim's age', 'Victim's gender', 'Victim's race',
#        'URL of image of victim', 'Date of Incident (month/day/year)',
#        'Street Address of Incident', 'City', 'State', 'Zipcode', 'County',
#        'Agency responsible for death', 'ORI Agency Identifier (if available)',
#        'Cause of death',
#        'A brief description of the circumstances surrounding the death',
#        'Official disposition of death (justified or other)',
#        'Criminal Charges?',
#        'Link to news article or photo of official document',
#        'Symptoms of mental illness?', 'Unarmed/Did Not Have an Actual Weapon',
#        'Alleged Weapon (Source: WaPo and Review of Cases Not Included in WaPo Database)',
#        'Alleged Threat Level (Source: WaPo)', 'Fleeing (Source: WaPo)',
#        'Body Camera (Source: WaPo)', 'WaPo ID (If included in WaPo database)',
#        'Off-Duty Killing?',
# ...

# %%
df_police_killings = df_police_killings[col_list]

# %%
df_police_killings.head()
# Out:
#              Victim's name Victim's age Victim's gender Victim's race  \
# 0  Name withheld by police      Unknown            Male  Unknown race
# 1  Name withheld by police      Unknown            Male  Unknown race
# 2  Name withheld by police           61            Male  Unknown race
# 3  Name withheld by police           22            Male  Unknown race
# 4          Steven D. Smith           33            Male  Unknown race
#
#   URL of image of victim Date of Incident (month/day/year)  \
# 0                    NaN                        06/09/2020
# 1                    NaN                        05/09/2020
# 2                    NaN                        05/09/2020
# 3                    NaN                        05/09/2020
# 4                    NaN                        04/09/2020
#
#    Street Address of Incident            City State  Zipcode  ...  \
# 0          337 Garrison Place  Virginia Beach    VA  23452.0  ...
# ...

# %%
col_list_2 = df_police_killings.columns.to_list()

# %%
col_list_2
# Out:
# ["Victim's name",
#  "Victim's age",
#  "Victim's gender",
#  "Victim's race",
#  'URL of image of victim',
#  'Date of Incident (month/day/year)',
#  'Street Address of Incident',
#  'City',
#  'State',
#  'Zipcode',
#  'County',
#  'Agency responsible for death',
#  'ORI Agency Identifier (if available)',
#  'Cause of death',
#  'A brief description of the circumstances surrounding the death',
#  'Official disposition of death (justified or other)',
#  'Criminal Charges?',
#  'Link to news article or photo of official document',
#  'Symptoms of mental illness?',
#  'Unarmed/Did Not Have an Actual Weapon',
#  'Alleged Weapon (Source: WaPo and Review of Cases Not Included in WaPo Database)',
#  'Alleged Threat Level (Source: WaPo)',
#  'Fleeing (Source: WaPo)',
#  'Body Camera (Source: WaPo)',
#  'WaPo ID (If included in WaPo database)',
#  'Off-Duty Killing?',
# ...

# %%
col_list_3 = ['victim_name', 'victim_age', 'victim_gender', 'victim_race', 'image_url', 'date_incident', 
              'address_incident', 'city', 'state', 'zipcode', 'county', 'agency', 'ori', 'cause_of_death', 
              'description', 'justified', 'criminal_charges', 'link', 'mental_illness', 'unarmed', 'alleged_weapon', 
              'threat_level', 'fleeing', 'body_camera', 'wapo_id', 'off_duty', 'geography', 'mpv_id', 'fe_id']

# %%
df_police_killings.columns = col_list_3

# %%
df_police_killings.head()
# Out:
#                victim_name victim_age victim_gender   victim_race image_url  \
# 0  Name withheld by police    Unknown          Male  Unknown race       NaN
# 1  Name withheld by police    Unknown          Male  Unknown race       NaN
# 2  Name withheld by police         61          Male  Unknown race       NaN
# 3  Name withheld by police         22          Male  Unknown race       NaN
# 4          Steven D. Smith         33          Male  Unknown race       NaN
#
#   date_incident            address_incident            city state  zipcode  \
# 0    06/09/2020          337 Garrison Place  Virginia Beach    VA  23452.0
# 1    05/09/2020  4900 South Lavergne Avenue         Chicago    IL  60638.0
# 2    05/09/2020      2118 Fredericksburg Rd     San Antonio    TX  78201.0
# 3    05/09/2020        2500 Logistics Drive    Battle Creek    MI  49037.0
# 4    04/09/2020         200 N. State Street        Syracuse    NY  13203.0
#
# ...

# %%
df_police_killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8427 entries, 0 to 8426
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   victim_name       8427 non-null   object
#  1   victim_age        8427 non-null   object
#  2   victim_gender     8415 non-null   object
#  3   victim_race       8427 non-null   object
#  4   image_url         4539 non-null   object
#  5   date_incident     8427 non-null   object
#  6   address_incident  8340 non-null   object
#  7   city              8421 non-null   object
#  8   state             8427 non-null   object
#  9   zipcode           8391 non-null   float64
#  10  county            8413 non-null   object
#  11  agency            8412 non-null   object
#  12  ori               8426 non-null   object
#  13  cause_of_death    8427 non-null   object
#  14  description       8410 non-null   object
#  15  justified         8416 non-null   object
# ...

# %%
df_police_killings['mpv_id'].value_counts()
# Out:
# 8449    2
# 5972    2
# 2047    1
# 7489    1
# 7465    1
#        ..
# 645     1
# 6790    1
# 4743    1
# 2700    1
# 2049    1
# Name: mpv_id, Length: 8425, dtype: int64

# %%
mpv_8449 = df_police_killings[df_police_killings['mpv_id']==8449]

# %%
mpv_8449
# Out:
#                   victim_name victim_age victim_gender   victim_race  \
# 3     Name withheld by police         22          Male  Unknown race
# 2180            Fernando Cruz         18          Male      Hispanic
#
#      image_url date_incident         address_incident          city state  \
# 3          NaN    05/09/2020     2500 Logistics Drive  Battle Creek    MI
# 2180       NaN    19/09/2018  3864 Whittier Boulevard   Los Angeles    CA
#
#       zipcode  ...                                unarmed alleged_weapon  \
# 3     49037.0  ...                                Vehicle        vehicle
# 2180  90023.0  ...  Unarmed/Did Not Have an Actual Weapon      no object
#
#      threat_level fleeing body_camera wapo_id off_duty geography mpv_id  \
# 3          attack     Car         NaN     NaN      NaN       NaN   8449
# 2180          NaN     NaN         NaN     NaN      NaN     Urban   8449
#
#         fe_id
# 3     28736.0
# 2180      NaN
#
# [2 rows x 29 columns]

# %%
mpv_5972 = df_police_killings[df_police_killings['mpv_id']==5972]

# %%
mpv_5972
# Out:
#                      victim_name victim_age victim_gender victim_race  \
# 2473             Guillermo Perez         32          Male    Hispanic
# 2474  Elizabeth Michele Tollison         49        Female       White
#
#      image_url date_incident address_incident      city state  zipcode  ...  \
# 2473       NaN    16/06/2018  6425 Tyrone Ave  Van Nuys    CA  91401.0  ...
# 2474       NaN    16/06/2018  6425 Tyrone Ave  Van Nuys    CA  91401.0  ...
#
#                                     unarmed alleged_weapon threat_level  \
# 2473                        Allegedly Armed          knife       attack
# 2474  Unarmed/Did Not Have an Actual Weapon      no object        other
#
#           fleeing body_camera wapo_id off_duty geography mpv_id    fe_id
# 2473  Not fleeing          No  3784.0      NaN     Urban   5972  24323.0
# 2474  Not fleeing          No  3784.0      NaN     Urban   5972  24323.0
#
# [2 rows x 29 columns]

# %%
df_police_killings = df_police_killings.drop([3, 2473])

# %%
df_police_killings['mpv_id'].value_counts()
# Out:
# 2047    1
# 3363    1
# 7465    1
# 1322    1
# 3371    1
#        ..
# 645     1
# 6790    1
# 4743    1
# 2700    1
# 2049    1
# Name: mpv_id, Length: 8425, dtype: int64

# %%
df_police_killings = df_police_killings.set_index('mpv_id')

# %%
df_police_killings.head()
# Out:
#                     victim_name victim_age victim_gender   victim_race  \
# mpv_id
# 8448    Name withheld by police    Unknown          Male  Unknown race
# 8446    Name withheld by police    Unknown          Male  Unknown race
# 8447    Name withheld by police         61          Male  Unknown race
# 8444            Steven D. Smith         33          Male  Unknown race
# 8445              Joshua Beedie         38          Male         White
#
#                                                 image_url date_incident  \
# mpv_id
# 8448                                                  NaN    06/09/2020
# 8446                                                  NaN    05/09/2020
# 8447                                                  NaN    05/09/2020
# 8444                                                  NaN    04/09/2020
# 8445    https://fatalencounters.org/wp-content/uploads...    04/09/2020
#
#                   address_incident            city state  zipcode  ...  \
# ...

# %%
df_police_killings = df_police_killings.sort_index()

# %%
df_police_killings.head()
# Out:
#                 victim_name victim_age victim_gender victim_race  \
# mpv_id
# 1               Mark Chavez         49          Male    Hispanic
# 2                Tyree Bell         31          Male       Black
# 3              Abel Gurrola         26          Male    Hispanic
# 4       Christopher Tavares         21          Male    Hispanic
# 5         Andrew L. Closson         21          Male       White
#
#                                                 image_url date_incident  \
# mpv_id
# 1       http://www.tricitytribuneusa.com/wp-content/up...    01/01/2013
# 2       http://content.omaha.com/media/maps/ps/2013/ja...    01/01/2013
# 3       http://www.bakersfieldnow.com/news/local/A-26-...    01/01/2013
# 4       http://www.krdo.com/image/view/-/17980228/medR...    01/01/2013
# 5       http://www.superiortelegram.com/sites/default/...    01/01/2013
#
#                              address_incident         city state  zipcode  \
# mpv_id
# ...

# %%
df_police_killings.columns
# Out:
# Index(['victim_name', 'victim_age', 'victim_gender', 'victim_race',
#        'image_url', 'date_incident', 'address_incident', 'city', 'state',
#        'zipcode', 'county', 'agency', 'ori', 'cause_of_death', 'description',
#        'justified', 'criminal_charges', 'link', 'mental_illness', 'unarmed',
#        'alleged_weapon', 'threat_level', 'fleeing', 'body_camera', 'wapo_id',
#        'off_duty', 'geography', 'fe_id'],
#       dtype='object')

# %%
df_police_killings['fe_id'].value_counts()
# Out:
# 25885.0    1
# 23826.0    1
# 16553.0    1
# 16260.0    1
# 15914.0    1
#           ..
# 28410.0    1
# 14239.0    1
# 28011.0    1
# 27959.0    1
# 12800.0    1
# Name: fe_id, Length: 8343, dtype: int64

# %%
cols_to_remove = ['victim_name', 'image_url', 'address_incident', 'ori', 'description', 'link']

# %%
df_police_killings = df_police_killings.drop(cols_to_remove, axis=1)

# %%
df_police_killings.head()
# Out:
#        victim_age victim_gender victim_race date_incident         city state  \
# mpv_id
# 1              49          Male    Hispanic    01/01/2013   Farmington    NM
# 2              31          Male       Black    01/01/2013        Omaha    NE
# 3              26          Male    Hispanic    01/01/2013  Bakersfield    CA
# 4              21          Male    Hispanic    01/01/2013       Pueblo    CO
# 5              21          Male       White    01/01/2013       Gordon    WI
#
#         zipcode    county                           agency cause_of_death  \
# mpv_id
# 1       87401.0  San Juan     Farmington Police Department        Gunshot
# 2       68111.0   Douglas          Omaha Police Department        Gunshot
# 3       93304.0      Kern    Bakersfield Police Department        Gunshot
# 4       81008.0    Pueblo         Pueblo Police Department        Gunshot
# 5       54838.0   Douglas  Douglas County Sheriff's Office        Gunshot
#
# ...

# %%
df_police_killings['victim_race'].value_counts()
# Out:
# White               3711
# Black               2121
# Hispanic            1455
# Unknown race         844
# Asian                130
# Native American      118
# Pacific Islander      46
# Name: victim_race, dtype: int64

# %%
df_police_killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8425 entries, 1 to 8452
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   victim_age        8425 non-null   object
#  1   victim_gender     8413 non-null   object
#  2   victim_race       8425 non-null   object
#  3   date_incident     8425 non-null   object
#  4   city              8419 non-null   object
#  5   state             8425 non-null   object
#  6   zipcode           8389 non-null   float64
#  7   county            8411 non-null   object
#  8   agency            8410 non-null   object
#  9   cause_of_death    8425 non-null   object
#  10  justified         8414 non-null   object
#  11  criminal_charges  8425 non-null   object
#  12  mental_illness    8416 non-null   object
#  13  unarmed           8425 non-null   object
#  14  alleged_weapon    8425 non-null   object
#  15  threat_level      5978 non-null   object
# ...

# %%
#df['Date']= pd.to_datetime(df['Date'])
df_police_killings['date_incident'] = pd.to_datetime(df_police_killings['date_incident'])

# %%
df_police_killings.head()
# Out:
#        victim_age victim_gender victim_race date_incident         city state  \
# mpv_id
# 1              49          Male    Hispanic    2013-01-01   Farmington    NM
# 2              31          Male       Black    2013-01-01        Omaha    NE
# 3              26          Male    Hispanic    2013-01-01  Bakersfield    CA
# 4              21          Male    Hispanic    2013-01-01       Pueblo    CO
# 5              21          Male       White    2013-01-01       Gordon    WI
#
#         zipcode    county                           agency cause_of_death  \
# mpv_id
# 1       87401.0  San Juan     Farmington Police Department        Gunshot
# 2       68111.0   Douglas          Omaha Police Department        Gunshot
# 3       93304.0      Kern    Bakersfield Police Department        Gunshot
# 4       81008.0    Pueblo         Pueblo Police Department        Gunshot
# 5       54838.0   Douglas  Douglas County Sheriff's Office        Gunshot
#
# ...
